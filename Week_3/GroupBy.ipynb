# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/census.csv')
df = df[df['SUMLEV'] == 50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
for state in df['STNAME'].unique():
    avg = np.average(df[df['STNAME'] == state].dropna()['CENSUS2010POP'])
    
    print('State ' + state + ' has average 2010 population of ' + str(avg))
# Out:
# State Alabama has average 2010 population of 71339.34328358209
# State Alaska has average 2010 population of 24490.724137931036
# State Arizona has average 2010 population of 426134.4666666667
# State Arkansas has average 2010 population of 38878.90666666667
# State California has average 2010 population of 642309.5862068966
# State Colorado has average 2010 population of 78581.1875
# State Connecticut has average 2010 population of 446762.125
# State Delaware has average 2010 population of 299311.3333333333
# State District of Columbia has average 2010 population of 601723.0
# State Florida has average 2010 population of 280616.5671641791
# State Georgia has average 2010 population of 60928.63522012578
# State Hawaii has average 2010 population of 272060.2
# State Idaho has average 2010 population of 35626.86363636364
# State Illinois has average 2010 population of 125790.50980392157
# State Indiana has average 2010 population of 70476.10869565218
# ...

# %%
# Out:
#       Name Age
# 0  William  18
# 1    Clara  17
# 2   Carlos  20
# 3  Dellano  37
# 4      Ana  56
